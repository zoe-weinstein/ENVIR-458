# %% [markdown]
# <a href="https://colab.research.google.com/github/zoe-weinstein/ENVIR-458/blob/main/FWS_458_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Lecture 10
# #### Seaborn

# %%
import seaborn as sns
import pandas as pd
import matplotlib as plt

# %%
penguins = sns.load_dataset("penguins")

# %%
sns.set_theme(context ="notebook", style = "darkgrid", palette = "deep")
sns.relplot(data = penguins,
            x = "bill_length_mm",
            y = "bill_depth_mm",
            hue = "species",
            size = "body_mass_g",
            style = "sex")

# %%
sns.set_theme(context ="notebook", style = "darkgrid", palette = "deep", font_scale = 1, color_codes = True, rc = None)
sns.displot(data = penguins,
            x = "flipper_length_mm",
            hue = "species",
            multiple = "stack",
            kind = "kde")

# %%
sns.histplot(data = penguins,
             x = "bill_length_mm",
             hue = "sex",
             fill = True)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
g = sns.PairGrid(data = penguins,
                 hue = "species",
                 corner = True)
g.map_lower(sns.scatterplot, marker = "+")
g.map_lower(sns.kdeplot)
g.map_diag(sns.histplot)
g

# %%
g = sns.FacetGrid(data = penguins,
                  col = "species",
                  row = "sex")
g.map(sns.regplot, "bill_length_mm", "bill_depth_mm")
